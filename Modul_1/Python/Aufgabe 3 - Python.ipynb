# %% [markdown]
# # Seattle Library - Datenanalyse

# %%
import urllib.request
import pandas as pd

# %% [markdown]
# #Checkouts über API beziehen und als CSV speichern

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2021&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7fd7c364cb20>)

# %% [markdown]
# #In einen Datenframe laden und analysieren

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2021              1
# 1       Digital    OverDrive        EBOOK          2021              1
# 2       Digital    OverDrive        EBOOK          2021              1
# 3       Digital    OverDrive        EBOOK          2021              1
# 4       Digital    OverDrive    AUDIOBOOK          2021              1
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon         BOOK          2021              1
# 9996    Digital    OverDrive        EBOOK          2021              1
# 9997   Physical      Horizon         BOOK          2021              1
# 9998   Physical      Horizon    VIDEODISC          2021              1
# 9999    Digital    OverDrive        EBOOK          2021              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df.shape
# Out:
# (10000, 11)

# %%
# Result: Seem like we only have enties from January 2021 - maybe need to further increase the data set and then subsample
checkouts_df["checkoutmonth"].unique()
# Out:
# array([1])

# %%
checkouts_df["checkouts"].max()
# Out:
# 431

# %%
checkouts_df["checkouts"].min()
# Out:
# 1

# %%
checkouts_df["checkouts"].median()
# Out:
# 2.0

# %%
checkouts_df["checkouts"].mean()
# Out:
# 3.3521

# %%
checkouts_df["usageclass"].unique()
# Out:
# array(['Digital', 'Physical'], dtype=object)

# %%
checkouts_df["materialtype"].unique()
# Out:
# array(['EBOOK', 'AUDIOBOOK', 'BOOK', 'SOUNDDISC', 'VIDEODISC',
#        'SOUNDDISC, VIDEODISC', 'REGPRINT', 'ATLAS', 'VIDEO', 'MUSIC',
#        'MICROFORM', 'MAP', 'ER', 'CR', 'LARGEPRINT', 'SOUNDREC'],
#       dtype=object)

# %%
checkouts_df[checkouts_df["materialtype"] == "VIDEODISC"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 69     Physical      Horizon    VIDEODISC          2021              1
# 83     Physical      Horizon    VIDEODISC          2021              1
# 95     Physical      Horizon    VIDEODISC          2021              1
# 106    Physical      Horizon    VIDEODISC          2021              1
# 113    Physical      Horizon    VIDEODISC          2021              1
# ...         ...          ...          ...           ...            ...
# 9953   Physical      Horizon    VIDEODISC          2021              1
# 9954   Physical      Horizon    VIDEODISC          2021              1
# 9977   Physical      Horizon    VIDEODISC          2021              1
# 9979   Physical      Horizon    VIDEODISC          2021              1
# 9998   Physical      Horizon    VIDEODISC          2021              1
#
#       checkouts                                              title creator  \
# ...

# %%
checkouts_df[checkouts_df["materialtype"] == "SOUNDREC"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 8915   Physical      Horizon     SOUNDREC          2021              1
#
#       checkouts               title creator  \
# 8915          1  Best sisters ever!     NaN
#
#                                                subjects      publisher  \
# 8915  Barbie Fictitious character Juvenile fiction, ...  Random House,
#
#      publicationyear
# 8915          [2016]

# %%
checkouts_df[checkouts_df["materialtype"] == "MUSIC"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 1164   Physical      Horizon        MUSIC          2021              1
# 4350   Physical      Horizon        MUSIC          2021              1
# 5337   Physical      Horizon        MUSIC          2021              1
# 5659   Physical      Horizon        MUSIC          2021              1
# 5854   Physical      Horizon        MUSIC          2021              1
# 6130   Physical      Horizon        MUSIC          2021              1
# 6653   Physical      Horizon        MUSIC          2021              1
# 7494   Physical      Horizon        MUSIC          2021              1
# 9522   Physical      Horizon        MUSIC          2021              1
#
#       checkouts                                              title  \
# 1164          1  Engel Lund's book of folk-songs; with pianofor...
# 4350          1  First 50 songs you should play on harp / arran...
# ...

# %%
checkouts_df[checkouts_df["materialtype"] == "SOUNDDISC"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 18     Physical      Horizon    SOUNDDISC          2021              1
# 26     Physical      Horizon    SOUNDDISC          2021              1
# 31     Physical      Horizon    SOUNDDISC          2021              1
# 35     Physical      Horizon    SOUNDDISC          2021              1
# 36     Physical      Horizon    SOUNDDISC          2021              1
# ...         ...          ...          ...           ...            ...
# 9869   Physical      Horizon    SOUNDDISC          2021              1
# 9924   Physical      Horizon    SOUNDDISC          2021              1
# 9932   Physical      Horizon    SOUNDDISC          2021              1
# 9973   Physical      Horizon    SOUNDDISC          2021              1
# 9987   Physical      Horizon    SOUNDDISC          2021              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df["creator"].unique()
# Out:
# array(['Kent Haruf', 'S. J. Watson', 'Amy Lane', ..., 'Usher, Sam',
#        'Sacks, Jonathan, 1948-2020', 'Susan Wittig Albert'], dtype=object)

# %%
checkouts_df["publisher"].unique()
# Out:
# array(['Random House, Inc.', 'HarperCollins Publishers Inc.',
#        'Dreamspinner Press', ..., 'Curve Music,', 'Revels Records,',
#        'Schocken Books,'], dtype=object)

# %%
checkouts_df[checkouts_df["materialtype"] == "MUSIC"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 1164   Physical      Horizon        MUSIC          2021              1
# 4350   Physical      Horizon        MUSIC          2021              1
# 5337   Physical      Horizon        MUSIC          2021              1
# 5659   Physical      Horizon        MUSIC          2021              1
# 5854   Physical      Horizon        MUSIC          2021              1
# 6130   Physical      Horizon        MUSIC          2021              1
# 6653   Physical      Horizon        MUSIC          2021              1
# 7494   Physical      Horizon        MUSIC          2021              1
# 9522   Physical      Horizon        MUSIC          2021              1
#
#       checkouts                                              title  \
# 1164          1  Engel Lund's book of folk-songs; with pianofor...
# 4350          1  First 50 songs you should play on harp / arran...
# ...

# %%
checkouts_df["materialtype"].value_counts()
# Out:
# EBOOK                   3919
# BOOK                    3279
# AUDIOBOOK               1602
# VIDEODISC                648
# SOUNDDISC                502
# REGPRINT                  14
# VIDEO                      9
# MUSIC                      9
# SOUNDDISC, VIDEODISC       7
# ER                         3
# MAP                        2
# CR                         2
# ATLAS                      1
# MICROFORM                  1
# LARGEPRINT                 1
# SOUNDREC                   1
# Name: materialtype, dtype: int64

# %%
# %matplotlib inline

# %%
checkouts_df["materialtype"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>
